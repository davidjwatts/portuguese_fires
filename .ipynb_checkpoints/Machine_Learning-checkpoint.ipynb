# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import utils
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import ElasticNetCV
from sklearn.linear_model import LassoCV
from sklearn.svm import SVR
from sklearn.model_selection import KFold
from sklearn.ensemble import GradientBoostingRegressor
import matplotlib.patches as mpatches

from sklearn.decomposition import PCA
import matplotlib.cm as cm
import seaborn as sns

# %matplotlib inline

# %%
fires = utils.wrangle()

# %%
fires.head()
# Out:
#    X  Y  month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5      3    6  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4     10    3  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4     10    7  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6      3    6  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6      3    1  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %% [markdown]
# ## Least Squares Regression Analysis

# %% [markdown]
# This analysis suggests the data is mostly noise. The R^2 value implies that guessing the mean would be similarly effective in predicting the fire size. The P-values suggest that temperature, rain, and humidity values could be scramble within the data frame, and you would get similar results when fitting it again.

# %%
# This regression analysis shows that we have some work in store for us.
# The connections between input variables and the target is extremely loose.

from statsmodels.formula.api import ols
fires['log'] = np.log(fires.area+1)
m = ols('log ~ temp + rain + RH + wind',fires).fit()
print(m.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    log   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.345
# Date:                Mon, 27 Mar 2017   Prob (F-statistic):              0.252
# Time:                        16:14:17   Log-Likelihood:                -903.77
# No. Observations:                 517   AIC:                             1818.
# Df Residuals:                     512   BIC:                             1839.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.7420      0.443      1.674      0.095        -0.129     1.613
# temp           0.0128      0.013      0.985      0.325        -0.013     0.038
# rain           0.0852      0.212      0.402      0.688        -0.331     0.501
# RH            -0.0028      0.005     -0.629      0.530        -0.012     0.006
# wind           0.0626      0.035      1.766      0.078        -0.007     0.132
# ==============================================================================
# Omnibus:                       91.211   Durbin-Watson:                   0.925
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              137.245
# Skew:                           1.189   Prob(JB):                     1.58e-30
# Kurtosis:                       3.847   Cond. No.                         365.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # PCA

# %% [markdown]
# Principle component analysis in this setting allows us to visualize our high dimensional data on a plane and see whether any natural structure presents itself.
#
# Unfortunately the meteorological data does not break up the fires by size. FWIC metrics seem to add structure, but it is only through the relationships that they have to each other, and not to the target variable.

# %%
# Here we can see how fire size is distributed across the two dimensions of greatest 
# variation with different subsets of features. 

X1 = fires.ix[:,[8,9, 10, 11]]
X2 = fires.ix[:,[0,1,2,3, 8, 9, 10, 11]]
X3 = fires.ix[:,[4, 5, 6, 7]]
X4 = fires.ix[:,1:12]

f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(12,12))

def pca_plot(data, ax):
    pca = PCA(n_components=2).fit_transform(data)
    return ax.scatter(pca[:,0], pca[:,1], c=fires.log, cmap=plt.cm.magma)

cax1 = pca_plot(X1, ax1)
cax2 = pca_plot(X2, ax2)
cax3 = pca_plot(X3, ax3)
cax4 = pca_plot(X4, ax4)

ax1.set_title("Meteorological Data")
ax2.set_title("Meteorological and Spatio/temporal")
ax3.set_title("FWIC Metrics")
ax4.set_title("All")

f.subplots_adjust(right=0.8)
cbar_ax = f.add_axes([0.85, 0.15, 0.05, 0.7])
f.colorbar(cax1, cax=cbar_ax)

f.subplots_adjust(hspace=.2)

plt.show()

# %% [markdown]
# # Features

# %% [markdown]
# Here we can determine which features to be included on all tests occurring below.

# %%
fires['sqrt_rain'] = np.sqrt(fires['rain'])

# %%
# Determine features
fires['sqrt_rain'] = np.sqrt(fires['rain'])

fires['sqrt_rain'] = fires
features = fires.ix[:,[8,9,10,11]]

#Scale input
X = scale(features)

#Take log of area and set y
y = np.log(fires.area.values+1).flatten()

# %%
# Unscale and evaluate MAE
def eval(y, y_):
    y1 = np.exp(y)-1
    y2 = np.exp(y_)-1
    score = np.mean(np.abs(y1-y2))
    return score

# %% [markdown]
# # Regression Techniques

# %% [markdown]
# Here I have created methods utilizing each of the regression algorithms that take in the data and spit out the mean standard error. The first three have built in cross-validation, while SVR does not.
#
# I perform parameter testing within each of the following sections, and then use the parameters in the final comparison section afterward.

# %% [markdown]
# ## Linear Regression

# %%
def LR(data):
    lr = LinearRegression()
    lr = lr.fit(data[0], data[2])
    y_ = lr.predict(data[1])
    return eval(y_, data[3])

# %% [markdown]
# ## Ridge Regression

# %%
def RR(data, alpha_array):
    ridge = RidgeCV(alphas=alpha_array)
    ridge = ridge.fit(data[0], data[2])
    y_ = ridge.predict(data[1])
    return eval(y_, data[3]), ridge.alpha_

# %%
# Average alpha of 30 iterations across 10-fold cross-validation 
results = []

a = [0.1, 1, 10, 100, 1000, 10000, 100000]
a = list(map(lambda x: float(x), a))

for i in range(30):
    kf = KFold(n_splits=10, shuffle=True, random_state=1)
    for tr, te in kf.split(X):
        data = (X[tr], X[te], y[tr].flatten(), y[te])
        results.append(RR(data, a)[1])        
            
print("average alpha: ",np.mean(results))
# Out:
# average alpha:  12700.0

# %%
# Average alpha across narrower, more accurate range

a = [10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000]
a = list(map(lambda x: float(x), a))

for i in range(30):
    kf = KFold(n_splits=10, shuffle=True, random_state=0)
    for tr, te in kf.split(X):
        data = (X[tr], X[te], y[tr].flatten(), y[te])
        results.append(RR(data, a)[1])        
            
print("average alpha: ",np.mean(results))
# Out:
# average alpha:  12350.0

# %% [markdown]
# ## Lasso

# %%
def Lasso(data):
    ll = LassoCV()
    ll = ll.fit(data[0], data[2])
    y_ = ll.predict(data[1])
    return eval(y_, data[3])

# %% [markdown]
# ## ElasticNet

# %%
def EN(data, l1_array, alpha_array):
    l1s = [.0001,.001,.01,.1, .5, .7, .9, .95, .99, 1]
    a = [.1, 1, 10, 100, 1000]
    en = ElasticNetCV(l1_ratio=l1_array, alphas=alpha_array)
    en = en.fit(data[0],data[2])
    y_ = en.predict(data[1])
    return eval(y_, data[3]), en.alpha_, en.l1_ratio_

# %%
# Testing for alpha and l1_ratio using across the grid of possibilities.

alpha_results = []
l1_results = []

l1s = [.0001,.001,.01,.1, .5, .7, .9, .95, .99, 1]
a = [1, 10, 100, 1000, 10000, 100000, 1000000]

for i in range(30):
    kf = KFold(n_splits=10, shuffle=True, random_state=1)
    for tr, te in kf.split(X):
        data = (X[tr], X[te], y[tr].flatten(), y[te])
        score, alpha, l1 = EN(data, l1s, a)
        alpha_results.append(alpha)
        l1_results.append(l1)
            
print("average alpha: ",np.mean(alpha_results))
print("average l1: ", np.mean(l1_results))
# Out:
# average alpha:  1000000.0
# average l1:  0.0001

# %% [markdown]
# These parameters makes sense because the algorithm wants to push all of the coeffecients to 0, and hence guess 0 for each fire. That would result in a better score than this model ends up achieving.

# %% [markdown]
# ## SVR

# %% [markdown]
# ### Linear

# %%
# Here I am performing testing within the call to the model. 

def SVR_lin(data, param=None):
    # 5 fold CV
    if param==None:
        chosen_cs=[]
        chosen_es=[]
        for tr, te in KFold(n_splits=5,shuffle=True, random_state=1).split(data[0]):
            c_cv = [None, np.inf, None]
            #test all cs for specific fold
            for c in [0.1, 0.25, 0.5, 0.75, 1, 1.25, 1.5]:
                e_cv=[None, np.inf]
                for e in [0.25, 0.30, 0.35, 0.4, 0.45, 0.5]:
                    svr = SVR(kernel='linear', C=c, epsilon=e)
                    svr = svr.fit(data[0][tr], data[2][tr])
                    y_ = svr.predict(data[0][te])
                    score = eval(y_, data[2][te])
                    if score < e_cv[1]:
                        e_cv[1] = score
                        e_cv[0] = e
                if e_cv[1] < c_cv[1]:
                    c_cv[1] = e_cv[1]
                    c_cv[0] = c
                    c_cv[2] = e_cv[0]
            chosen_cs.append(c_cv[0])
            chosen_es.append(c_cv[2])
        
        best_c = np.mean(chosen_cs)
        best_e = np.mean(chosen_es)
    else:
        best_c = param[0]
        best_e = param[1]
    
    #run linear SVR with best c
    svr = SVR(kernel='linear', C=best_c, epsilon=best_e)
    svr = svr.fit(data[0], data[2])
    y_ = svr.predict(data[1])
    return eval(y_, data[3]), svr.C, svr.epsilon

# %%
# Testing C and epsilon values

c_results=[]
eps_results=[]

kf = KFold(n_splits=5, shuffle=True, random_state=1)

for tr, te in kf.split(X):
    data = (X[tr], X[te], y[tr].flatten(), y[te])
    score, C_value, eps_value = SVR_lin(data)
    c_results.append(C_value)
    eps_results.append(eps_value)

print("Average C: ", np.mean(c_results))
print("Average epsilon: ", np.mean(eps_results))
# Out:
# Average C:  0.652
# Average epsilon:  0.378

# %% [markdown]
# ### Rbf

# %%
def SVR_rbf(data, param=None):
    # 5 fold CV
    if param==None:
        chosen_cs=[]
        chosen_es=[]
        for tr, te in KFold(n_splits=5,shuffle=True, random_state=1).split(data[0]):
            c_cv = [None, np.inf, None]
            #test all cs for specific fold
            for c in [0.1, 1, 1.5, 2, 2.5, 3, 3.5, 4, 10]:
                e_cv=[None, np.inf]
                for e in [0.25, 0.30, 0.35, .4, 0.45]:
                    svr = SVR(kernel='rbf', C=c, epsilon=e, gamma=0.075)
                    svr = svr.fit(data[0][tr], data[2][tr])
                    y_ = svr.predict(data[0][te])
                    score = eval(y_, data[2][te])
                    if score < e_cv[1]:
                        e_cv[1] = score
                        e_cv[0] = e
                if e_cv[1] < c_cv[1]:
                    c_cv[1] = e_cv[1]
                    c_cv[0] = c
                    c_cv[2] = e_cv[0]
            chosen_cs.append(c_cv[0])
            chosen_es.append(c_cv[2])
        
        best_c = np.mean(chosen_cs)
        best_e = np.mean(chosen_es)
        gam = 0.075
    else:
        best_c = param[0]
        best_e = param[1]
        gam = param[2]
        
    #run linear SVR with best c
    svr = SVR(kernel='rbf', C=best_c, epsilon=best_e, gamma=gam)
    svr = svr.fit(data[0], data[2])
    y_ = svr.predict(data[1])
    return eval(y_, data[3]), best_c, best_e

# %%
# Testing C and epsilon values

c_results=[]
eps_results=[]

kf = KFold(n_splits=5, shuffle=True, random_state=1)

for tr, te in kf.split(X):
    data = (X[tr], X[te], y[tr].flatten(), y[te])
    score, C_value, eps_value = SVR_rbf(data)
    c_results.append(C_value)
    eps_results.append(eps_value)

print("Average C: ", np.mean(c_results))
print("Average epsilon: ", np.mean(eps_results))
# Out:
# Average C:  4.756
# Average epsilon:  0.294

# %%
# Testing different gamma values

gamma_results=[]

gammas=[0.025, 0.05, 0.075, 0.1, 0.125, 0.15]

kf = KFold(n_splits=5, shuffle=True, random_state=1)

for tr, te in kf.split(X):
    g_cv = [None, np.inf]
    for g in gammas:
        data = (X[tr], X[te], y[tr].flatten(), y[te])
        score, C_value, eps_value= SVR_rbf(data, (4.76, 0.294, g))
        if score < g_cv[1]:
            g_cv[1] = score
            g_cv[0] = g
    gamma_results.append(g_cv[0])
    
print("Average gamma: ", np.mean(gamma_results))
# Out:
# Average gamma:  0.075

# %% [markdown]
# ## Gradient Boosting Regressor

# %%
def GBR(data):
    adr = GradientBoostingRegressor(loss='lad', criterion='mae', max_depth=1)
    adr = adr.fit(data[0], data[2])
    y_ = adr.predict(data[1])
    return eval(y_, data[3])

# %% [markdown]
# ## Hybrid - SVR and GBR

# %%
def hybrid(data):
    svr = SVR(kernel='rbf', C=4.76, epsilon=0.294, gamma=0.075)
    svr = svr.fit(data[0], data[2])
    y1_ = svr.predict(data[1])
    adr = GradientBoostingRegressor(loss='lad', criterion='mae', max_depth=1)
    adr = adr.fit(data[0], data[2])
    y2_ = adr.predict(data[1])
    y_ = (y1_ + y2_)/2
    return eval(y_, data[3]), y_

# %% [markdown]
# # Results of 30 trials

# %%
# As a benchmark, guessing 0 for every fire gives an MAE error of:
np.mean(fires.area.values)
# Out:
# 12.847292069632493

# %%
# **WARNING Takes a few minutes to process**
#Because this takes a while to run, here are the most recent results:

results = {
    'Linear Regression':[],
    'Ridge Regression':[],
    'Elastic Net':[],
    'Lasso':[],
    'SVR Linear':[],
    'GBR':[],
    'SVR Rbf':[],
    'Hybrid':[]
}

for i in range(30):
    
    kf = KFold(n_splits=10, shuffle=True, random_state=1)
    for tr, te in kf.split(X):
        data = (X[tr], X[te], y[tr].flatten(), y[te])
        results['Linear Regression'].append(LR(data))
        results['Ridge Regression'].append(RR(data, [12350.0])[0])
        results["Lasso"].append(Lasso(data))
        results['Elastic Net'].append(EN(data, [0.0001],[1000000.0])[0])
        results['SVR Linear'].append(SVR_lin(data, (0.652,0.378))[0])
        results["GBR"].append(GBR(data))
        results['SVR Rbf'].append(SVR_rbf(data, (4.76,0.294, 0.075))[0])
        results['Hybrid'].append(hybrid(data)[0])
        

for key, value in results.items():
    print(key, ": ", np.mean(value))
# Out:
# Linear Regression :  12.9964372058
# Ridge Regression :  12.9760234269
# Elastic Net :  12.9761154411
# Lasso :  12.9761154411
# SVR Linear :  12.8414530887
# GBR :  12.6952010812
# SVR Rbf :  12.6720677628
# Hybrid :  12.6635299975

# %%
# **WARNING takes a few minutes to process**

prediction = np.array([])
actual = np.array([])

for i in range(30):
    kf = KFold(n_splits=10, shuffle=True)
    for tr, te in kf.split(X):
        data = (X[tr], X[te], y[tr].flatten(), y[te])
        y_ = hybrid(data)[1]
        prediction = np.concatenate((prediction, y_))
        actual = np.concatenate((actual, te))

# %% [markdown]
# This graph comparing predictions and actual sizes is telling. Many of the predictions seem to just be a guess in the 0-5 region, while predictions venture into the +5 region when the fires actually are larger than 5. A prediction of less than 5 may not be very meaningful, but a prediction of greater than 10 is highly indicative of a fire greater than 5.

# %%
# Comparing predictions with actual fire size

Results = pd.DataFrame()
actual = actual.astype(np.int)
Results['y'] = fires.area.values[actual]
Results['hat'] = np.exp(prediction) - 1
Results['abs_err'] = np.abs(Results.y-Results.hat)

test_grid = np.transpose([range(len(Results)), np.sort(Results.y.values)])
pred_grid = np.transpose([range(len(Results)), Results.sort_values('y').hat.values])

plt.scatter(pred_grid[:,0], pred_grid[:,1], c='b', alpha=0.2, label='predictions')
plt.scatter(test_grid[:,0], test_grid[:,1], c='r',alpha=0.01, label='actual size')
plt.ylim((0,30))
plt.title("Predictions vs Actual fire size")
plt.ylabel('Area')
plt.xlabel('# in set')
red_patch = mpatches.Patch(color='red', label='Actual Area')
blue_patch = mpatches.Patch(color='blue', label='Predictions')
plt.legend(handles=[red_patch, blue_patch],bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# The regression error characteristic curve suggests that the model contains many predictions within a quite reasonable error threshold. For example, 60% of the predictions are within 2 hecatres of error.  However, the tail suggests an extreme degree error for 10% or more of the test predictions.

# %%
# REC curve of the ensemble method vs guessing the mean fire size. 

rec = np.transpose([np.sort(Results['abs_err'].values), 
        np.array(range(len(Results)))/len(Results)])

rec_mean = np.transpose([np.sort(Results.y),
        np.array(range(len(Results)))/len(Results) ])

plt.scatter(rec[:,0], rec[:,1], c='b')
plt.scatter(rec_mean[:,0], rec_mean[:,1], c='r')
plt.xlim((-1,30))
plt.title('REC curve: Hybrid vs Guess 0')
plt.xlabel('Error size')
plt.ylabel('% of predictions')
red_patch = mpatches.Patch(color='red', label='Predicting 0')
blue_patch = mpatches.Patch(color='blue', label='Hybrid model')
plt.legend(handles=[red_patch, blue_patch],bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
